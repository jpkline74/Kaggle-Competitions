# %% [markdown]
# #  Mental Health in the Tech Industry

# %% [markdown]
# > This data set measures the attitudes towards mental health and frequency of mental health disorders in the tech workplace.
# I will be using machine learning on this data set to analyze the data and see if we can predict which employees are in need of treatment.

# %% [markdown]
# __Link to dataset__ <br>
# https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed

# %% [markdown]
# <br>

# %% [markdown]
# ## Data Exploration/Preprocessing

# %% [markdown]
# First, we need to do a little data exploration, see if there is any missing data and how we should tackle the missing values. After that we will preprocess the data, encode categorical data, fix errors within the data, etc. We can also come back to this process to enhance our model after making preliminary models. Let's import our python modules, and check out the data set.

# %%
import time
import numpy as np
import pandas as pd

import sklearn
from IPython.display import display
from sklearn.model_selection import train_test_split
from pandas.api.types import is_numeric_dtype
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV as gscv
from sklearn.model_selection import RandomizedSearchCV as rscv
import warnings
from itertools import permutations
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

warnings.filterwarnings('ignore')

pd.options.display.max_columns = None
pd.options.display.max_rows = 50

filepath = 'C:\\Users\\jpkli\\Desktop\\Machine Learning Projects\\Mental Health\\survey'

df_1 = pd.read_csv(f'{filepath}.csv')

# %%
df_1.head(15)
# Out:
#               Timestamp  Age  Gender         Country state self_employed  \
# 0   2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1   2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2   2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3   2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4   2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5   2014-08-27 11:31:22   33    Male   United States    TN           NaN
# 6   2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 7   2014-08-27 11:32:05   39       M          Canada   NaN           NaN
# 8   2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 9   2014-08-27 11:32:43   23    Male          Canada   NaN           NaN
# 10  2014-08-27 11:32:44   31    Male   United States    OH           NaN
# 11  2014-08-27 11:32:49   29    male        Bulgaria   NaN           NaN
# 12  2014-08-27 11:33:23   42  female   United States    CA           NaN
# 13  2014-08-27 11:33:26   36    Male   United States    CT           NaN
# 14  2014-08-27 11:33:57   27    Male          Canada   NaN           NaN
#
#    family_history treatment work_interfere    no_employees remote_work  \
# 0              No       Yes          Often            6-25          No
# 1              No        No         Rarely  More than 1000          No
# 2              No        No         Rarely            6-25          No
# 3             Yes       Yes          Often          26-100          No
# 4              No        No          Never         100-500         Yes
# 5             Yes        No      Sometimes            6-25          No
# 6             Yes       Yes      Sometimes             1-5         Yes
# 7              No        No          Never             1-5         Yes
# 8             Yes       Yes      Sometimes         100-500          No
# 9              No        No          Never          26-100          No
# 10             No       Yes      Sometimes            6-25         Yes
# 11             No        No          Never         100-500         Yes
# 12            Yes       Yes      Sometimes          26-100          No
# 13            Yes        No          Never        500-1000          No
# 14             No        No          Never            6-25          No
#
#    tech_company    benefits care_options wellness_program   seek_help  \
# 0           Yes         Yes     Not sure               No         Yes
# 1            No  Don't know           No       Don't know  Don't know
# 2           Yes          No           No               No          No
# 3           Yes          No          Yes               No          No
# 4           Yes         Yes           No       Don't know  Don't know
# 5           Yes         Yes     Not sure               No  Don't know
# 6           Yes          No           No               No          No
# 7           Yes          No          Yes               No          No
# 8           Yes         Yes          Yes               No          No
# 9           Yes  Don't know           No       Don't know  Don't know
# 10          Yes  Don't know           No               No          No
# 11          Yes  Don't know     Not sure               No          No
# 12           No         Yes          Yes               No          No
# 13          Yes  Don't know     Not sure               No  Don't know
# 14          Yes  Don't know     Not sure       Don't know  Don't know
#
#      anonymity               leave mental_health_consequence  \
# 0          Yes       Somewhat easy                        No
# 1   Don't know          Don't know                     Maybe
# 2   Don't know  Somewhat difficult                        No
# 3           No  Somewhat difficult                       Yes
# 4   Don't know          Don't know                        No
# 5   Don't know          Don't know                        No
# 6           No  Somewhat difficult                     Maybe
# 7          Yes          Don't know                        No
# 8           No      Very difficult                     Maybe
# 9   Don't know          Don't know                        No
# 10  Don't know          Don't know                        No
# 11  Don't know          Don't know                        No
# 12  Don't know  Somewhat difficult                       Yes
# 13  Don't know          Don't know                        No
# 14  Don't know       Somewhat easy                        No
#
#    phys_health_consequence     coworkers    supervisor  \
# 0                       No  Some of them           Yes
# 1                       No            No            No
# 2                       No           Yes           Yes
# 3                      Yes  Some of them            No
# 4                       No  Some of them           Yes
# 5                       No           Yes           Yes
# 6                    Maybe  Some of them            No
# 7                       No            No            No
# 8                       No           Yes           Yes
# 9                       No           Yes           Yes
# 10                      No  Some of them           Yes
# 11                      No           Yes           Yes
# 12                     Yes           Yes           Yes
# 13                      No           Yes           Yes
# 14                      No  Some of them  Some of them
#
#    mental_health_interview phys_health_interview mental_vs_physical  \
# 0                       No                 Maybe                Yes
# 1                       No                    No         Don't know
# 2                      Yes                   Yes                 No
# 3                    Maybe                 Maybe                 No
# 4                      Yes                   Yes         Don't know
# 5                       No                 Maybe         Don't know
# 6                       No                    No         Don't know
# 7                       No                    No                 No
# 8                       No                 Maybe                 No
# 9                    Maybe                 Maybe                Yes
# 10                      No                    No         Don't know
# 11                     Yes                   Yes         Don't know
# 12                   Maybe                 Maybe                 No
# 13                      No                    No         Don't know
# 14                   Maybe                   Yes                Yes
#
#    obs_consequence                                           comments
# 0               No                                                NaN
# 1               No                                                NaN
# 2               No                                                NaN
# 3              Yes                                                NaN
# 4               No                                                NaN
# 5               No                                                NaN
# 6               No                                                NaN
# 7               No                                                NaN
# 8               No                                                NaN
# 9               No                                                NaN
# 10              No                                                NaN
# 11              No                                                NaN
# 12             Yes                                                NaN
# 13              No  I'm not on my company's health insurance which...
# 14              No                                                NaN

# %% [markdown]
# <br>

# %% [markdown]
# As we can see from a glimps of the data, there are missing values, typos, and a timestamp column. For this data in particular the timestamp relates to when each individual person submitted their survey, and is not representing multiple surveys from individuals, so for the time being I will drop that column. (May come back to this later). Also, the comments section may be useful to read, but for our current purposes we will not be using that column.
#
# Lets take a look at our columns with missing data.

# %%
df_1 = df_1.drop(['comments'], axis = 1)
df_1 = df_1.drop(['Timestamp'], axis = 1)
display(df_1.isnull().sum())
# Out:
# Age                            0
# Gender                         0
# Country                        0
# state                        515
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               264
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %% [markdown]
# <br>
# Even though the 'state' column is missing about 41% of its data, it isn't as bad as it seems. Most of the missing state values are due to the fact that they are in a country without states. So I will try to work with that in this dataset.
# <br>

# %%
subset = df_1[(df_1['Country'] == 'United States') & (df_1['state'].isnull())]
subset
# Out:
#       Age  Gender        Country state self_employed family_history treatment  \
# 52     31       M  United States   NaN            No             No        No
# 294    56    Male  United States   NaN            No             No       Yes
# 367    36    Male  United States   NaN            No            Yes       Yes
# 525    41  Female  United States   NaN            No            Yes       Yes
# 574    50    Male  United States   NaN            No             No        No
# 596    24  Female  United States   NaN            No            Yes       Yes
# 638    35    Male  United States   NaN           Yes             No        No
# 817    44    male  United States   NaN           Yes            Yes       Yes
# 854    31    Male  United States   NaN            No            Yes        No
# 926    43       M  United States   NaN            No            Yes        No
# 1019   25    Male  United States   NaN            No             No        No
#
#      work_interfere    no_employees remote_work tech_company    benefits  \
# 52              NaN         100-500         Yes          Yes  Don't know
# 294           Never  More than 1000          No          Yes         Yes
# 367           Often         100-500          No          Yes          No
# 525          Rarely        500-1000         Yes          Yes         Yes
# 574           Never          26-100         Yes          Yes          No
# 596       Sometimes         100-500          No          Yes         Yes
# 638             NaN             1-5         Yes          Yes         Yes
# 817       Sometimes             1-5         Yes          Yes          No
# 854             NaN            6-25          No          Yes  Don't know
# 926       Sometimes        500-1000          No           No         Yes
# 1019         Rarely          26-100         Yes          Yes  Don't know
#
#      care_options wellness_program   seek_help   anonymity  \
# 52             No       Don't know  Don't know  Don't know
# 294      Not sure       Don't know  Don't know  Don't know
# 367           Yes               No          No         Yes
# 525           Yes              Yes         Yes         Yes
# 574           Yes               No          No  Don't know
# 596      Not sure               No          No  Don't know
# 638      Not sure               No          No         Yes
# 817           Yes               No          No          No
# 854      Not sure               No          No  Don't know
# 926      Not sure               No  Don't know  Don't know
# 1019           No               No          No  Don't know
#
#                    leave mental_health_consequence phys_health_consequence  \
# 52            Don't know                     Maybe                   Maybe
# 294           Don't know                        No                   Maybe
# 367            Very easy                        No                      No
# 525            Very easy                     Maybe                   Maybe
# 574           Don't know                        No                      No
# 596   Somewhat difficult                       Yes                   Maybe
# 638            Very easy                        No                      No
# 817            Very easy                       Yes                     Yes
# 854           Don't know                     Maybe                      No
# 926           Don't know                     Maybe                      No
# 1019       Somewhat easy                       Yes                      No
#
#          coworkers    supervisor mental_health_interview  \
# 52    Some of them  Some of them                   Maybe
# 294            Yes  Some of them                      No
# 367   Some of them  Some of them                      No
# 525   Some of them  Some of them                      No
# 574             No            No                      No
# 596             No            No                      No
# 638   Some of them           Yes                      No
# 817   Some of them            No                      No
# 854   Some of them  Some of them                      No
# 926             No  Some of them                      No
# 1019  Some of them  Some of them                      No
#
#      phys_health_interview mental_vs_physical obs_consequence
# 52                   Maybe         Don't know              No
# 294                  Maybe         Don't know              No
# 367                     No         Don't know              No
# 525                     No                Yes              No
# 574                  Maybe                 No              No
# 596                     No                 No             Yes
# 638                     No                Yes              No
# 817                     No                Yes              No
# 854                     No         Don't know              No
# 926                  Maybe                 No              No
# 1019                   Yes         Don't know             Yes

# %%
df_1['state'].value_counts()
# Out:
# 740

# %% [markdown]
# <br>
# Seeing that only 11 of the rows missing values in state, we will replace those missing values with the mode, which happens to be California. For every other missing value we will replace with 'other'. This can be an area that we go back to later to try and be more precise with replacing the missing data.

# %% [markdown]
# <br>

# %%
df_1 = df_1[df_1['Country'] == 'United States'].fillna(df_1['state'] == 'CA')

# %%
df_1['state'].value_counts().
# Out:
# CA    138
# WA     70
# NY     56
# TN     45
# TX     44
# OH     30
# PA     29
# OR     29
# IL     28
# IN     27
# MI     22
# MN     21
# MA     20
# FL     15
# NC     14
# VA     14
# GA     12
# WI     12
# MO     12
# UT     10
# CO      9
# AL      8
# MD      7
# AZ      7
# OK      6
# NJ      6
# KY      5
# SC      5
# DC      4
# IA      4
# CT      4
# NV      3
# NH      3
# SD      3
# VT      3
# KS      3
# WY      2
# NE      2
# NM      2
# MS      1
# ME      1
# RI      1
# LA      1
# ID      1
# WV      1
# Name: state, dtype: int64
